# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
np.random.seed(42)

# %% [markdown]
# The PDF for $e^X$ is $\frac{1}{\sqrt{2\pi}y}e^{-\log^2(x)/2}$. We plot this using the arrays $x$ and $y$ below.

# %%
x = np.arange(-1, 10, 0.01)

# %%
y = np.where(x>0, 1/(np.sqrt(2*np.pi)*x) * np.exp(-np.log(x)**2/2), 0)
# Out:
# /var/folders/h9/7qb3ygvs0mzb0cdjbh8z8svr0000gn/T/ipykernel_88449/1909324375.py:1: RuntimeWarning: invalid value encountered in log
#   y = np.where(x>0, 1/(np.sqrt(2*np.pi)*x) * np.exp(-np.log(x)**2/2), 0)

# %% [markdown]
# Below we generate $Y=e^X$ 10,000 times to draw a histogram for $Y$.

# %%
X = np.random.normal(loc=0, scale=1, size=int(1e4))

# %%
Y = np.exp(xr)

# %%
bins = np.arange(0, 10, 0.2)
plt.hist(Y, bins=bins, density=True, histtype='step')
plt.plot(x, y)
plt.title('Histogram of $e^X$ versus graph of PDF for $e^X$')
# Out:
# Text(0.5, 1.0, 'Histogram of $e^X$ versus graph of PDF for $e^X$')

# %% [markdown]
# We see that the histogram matches the graph of the PDF quite closely.
